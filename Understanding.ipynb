# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv('Jobs_Data.csv')

# %%
df.shape
df.info()
df.sample(5)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            120 non-null    int64
#  1   Name                  120 non-null    str
#  2   Rating                120 non-null    float64
#  3   Reviews               120 non-null    str
#  4   Salaries              120 non-null    str
#  5   Interviews            120 non-null    str
#  6   Jobs                  120 non-null    str
#  7   Benefits              120 non-null    str
#  8   Highly_Rated_for      120 non-null    str
#  9   Critically_Rated_for  55 non-null     str
# dtypes: float64(1), int64(1), str(8)
# memory usage: 9.5 KB
#      Unnamed: 0                 Name  Rating Reviews Salaries Interviews Jobs  \
# 118         118                Udaan     3.9    5.7k    14.8k        376   --
# 39           39  Mahindra & Mahindra     4.0   12.2k    41.1k        891    6
# 61           61              Samsung     3.9    8.4k    26.3k        638   55
# 100         100  Indiamart Intermesh     3.5    6.1k    21.8k        785  232
# 110         110          GlobalLogic     3.5    5.9k    41.9k        697   82
#
#     Benefits                                  Highly_Rated_for  \
# 118      762                                            Salary
# 39      1.2k  Job Security, Skill Development, Company Culture
# 61       535                                            Salary
# 100      476    Work Satisfaction, Promotions, Company Culture
# 110      535             Promotions, Salary, Work Satisfaction
#
#          Critically_Rated_for
# 118  Job Security, Promotions
# 39                 Promotions
# 61                 Promotions
# 100                       NaN
# 110                       NaN

# %%
#are there any missing value
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Name                     0
# Rating                   0
# Reviews                  0
# Salaries                 0
# Interviews               0
# Jobs                     0
# Benefits                 0
# Highly_Rated_for         0
# Critically_Rated_for    65
# dtype: int64

# %%
#how data look mathematically
df.describe()
# Out:
#        Unnamed: 0      Rating
# count  120.000000  120.000000
# mean    59.500000    3.776667
# std     34.785054    0.301741
# min      0.000000    3.000000
# 25%     29.750000    3.600000
# 50%     59.500000    3.800000
# 75%     89.250000    3.925000
# max    119.000000    4.700000

# %%
#are there duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#how is the correlation between cols
df.corr()

# %% [markdown]
# # Categorical Analysis

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.countplot(x = df['Survived'])
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ##

# %%
sns.countplot(x=df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind = 'pie', autopct='%.2f')
# Out:
# <Axes: >

# %% [markdown]
# # Numerical Data

# %%
#Histogram
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins = 10)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
#Distplot  pdf
sns.distplot(df['Age'])
# Out:
# C:\Users\malik\AppData\Local\Temp\ipykernel_26628\982309678.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#Boxplot FOR NOISY DATA
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].min()
# Out:
# np.float64(0.42)

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()     #near zero means normal distributio n
# Out:
# np.float64(0.38910778230082704)
